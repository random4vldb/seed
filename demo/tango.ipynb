# %%
from tango import Workspace
workspace = Workspace.from_url("local:///root/workspace/read/temp/training")
result = workspace.step_result_for_run("tapas_infotab_pipeline", "evaluation")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/envs/read/lib/python3.8/site-packages/tango/workspace.py:241, in Workspace.step_result_for_run(self, run_name, step_name)
#     240 try:
# --> 241     return self.step_cache[step_info]
#     242 except KeyError:
#
# File /opt/conda/envs/read/lib/python3.8/site-packages/tango/step_caches/local_step_cache.py:115, in LocalStepCache.__getitem__(self, step)
#     114 if step not in self:
# --> 115     raise KeyError(step)
#     116 metadata = CacheMetadata.from_params(Params.from_file(self._metadata_path(step)))
#
# KeyError: StepInfo(unique_id='Evaluation-0056-48C5w6rXyLdY3J33MS1JpBoUGE5bacxd', step_class_name='Evaluation', dependencies={'SentenceSelection-00672-3o1rfZwKS4UEY797aEVhkbpCmeENoYqC', 'TableVerification-0061-v4QmNg1nWJa4Vo1jibdfAgktMUcC5v9F', 'DocumentRetrieval-0041-2dg5UxaZ6j9SL2ytLJ3bdrXvF1MyHCeG', 'InfotabInputData-0013-5nZZNHj3i1Kh8vXwJghUMfv6Abxq9rbF'}, cacheable=True, step_name='evaluation', version='0056', start_time=None, end_time=None, error=None, result_location=None, config={'data': {'type': 'ref', 'ref': 'InfotabInputData-0013-5nZZNHj3i1Kh8vXwJghUMfv6Abxq9rbF'}, 'doc_results': {'type': 'ref', 'ref': 'DocumentRetrieval-0041-2dg5UxaZ6j9SL2ytLJ3bdrXvF1MyHCeG'}, 'sentence_results': {'type': 'ref', 'ref': 'SentenceSelection-00672-3o1rfZwKS4UEY797aEVhkbpCmeENoYqC'}, 'type': 'pipeline::evaluation', 'verified_results': {'type': 'ref', 'ref': 'TableVerification-0061-v4QmNg1nWJa4Vo1jibdfAgktMUcC5v9F'}}, metadata={}, platform=PlatformMetadata(operating_system='Linux-5.4.0-89-generic-x86_64-with-glibc2.17', cpu_count=48, user='root', host='70c96f053a50'), environment=EnvironmentMetadata(python='3.8.13', executable=PosixPath('/opt/conda/envs/read/bin/python'), command='/opt/conda/envs/read/bin/tango run config/tapas/pipeline_totto_tapas.jsonnet -n tapas_infotab_pipeline -i read -w temp/training', root=PosixPath('/root/workspace/read'), packages=[('absl-py', '1.2.0'), ('accelerate', '0.12.0'), ('ai2-tango', '0.14.0'), ('aiohttp', '3.8.3'), ('aiohttp-cors', '0.7.0'), ('aiosignal', '1.2.0'), ('antlr4-python3-runtime', '4.9.3'), ('anyio', '3.5.0'), ('argon2-cffi', '21.3.0'), ('argon2-cffi-bindings', '21.2.0'), ('asttokens', '2.0.8'), ('astunparse', '1.6.3'), ('async-timeout', '4.0.2'), ('attrs', '22.1.0'), ('babel', '2.9.1'), ('backcall', '0.2.0'), ('base58', '2.1.1'), ('beaker-py', '1.10.3'), ('beautifulsoup4', '4.11.1'), ('black', '22.10.0'), ('bleach', '4.1.0'), ('blessed', '1.19.1'), ('blingfire', '0.1.8'), ('blis', '0.7.8'), ('boto3', '1.24.88'), ('botocore', '1.27.88'), ('bpemb', '0.3.4'), ('brotlipy', '0.7.0'), ('bs4', '0.0.1'), ('cached-path', '1.1.6'), ('cachetools', '5.2.0'), ('catalogue', '2.0.8'), ('certifi', '2022.9.24'), ('cffi', '1.15.1'), ('charset-normalizer', '2.1.1'), ('chex', '0.1.5'), ('click', '8.0.4'), ('click-help-colors', '0.9.1'), ('cloudpickle', '2.2.0'), ('colorama', '0.4.5'), ('coloredlogs', '15.0.1'), ('colorful', '0.5.4'), ('commonmark', '0.9.1'), ('confection', '0.0.3'), ('conllu', '4.5.2'), ('contourpy', '1.0.5'), ('cryptography', '37.0.1'), ('cupy-cuda113', '10.6.0'), ('cycler', '0.11.0'), ('cymem', '2.0.6'), ('cython', '0.29.32'), ('datasets', '2.5.2'), ('debugpy', '1.6.3'), ('decorator', '5.1.1'), ('defusedxml', '0.7.1'), ('deprecated', '1.2.13'), ('dill', '0.3.5.1'), ('distlib', '0.3.6'), ('dm-tree', '0.1.7'), ('docker', '6.0.0'), ('docker-pycreds', '0.4.0'), ('elasticsearch', '7.17.6'), ('elasticsearch-dsl', '7.4.0'), ('en-core-web-sm', '3.4.0'), ('entrypoints', '0.4'), ('etils', '0.8.0'), ('evaluate', '0.2.2'), ('executing', '1.0.0'), ('fairscale', '0.4.9'), ('faiss', '1.7.2'), ('fastjsonschema', '2.16.2'), ('fastrlock', '0.8'), ('filelock', '3.8.0'), ('flair', '0.11.3'), ('flatbuffers', '22.9.24'), ('flax', '0.5.0'), ('fonttools', '4.37.4'), ('frozenlist', '1.3.1'), ('fsspec', '2022.8.2'), ('ftfy', '6.1.1'), ('future', '0.18.2'), ('gast', '0.4.0'), ('gdown', '4.4.0'), ('gensim', '4.2.0'), ('gitdb', '4.0.9'), ('gitpython', '3.1.28'), ('glob2', '0.7'), ('google-api-core', '2.8.2'), ('google-auth', '2.12.0'), ('google-auth-oauthlib', '0.4.6'), ('google-cloud-core', '2.3.2'), ('google-cloud-storage', '2.5.0'), ('google-crc32c', '1.5.0'), ('google-pasta', '0.2.0'), ('google-resumable-media', '2.4.0'), ('googleapis-common-protos', '1.56.4'), ('gpustat', '1.0.0'), ('grpcio', '1.43.0'), ('h5py', '3.7.0'), ('huggingface-hub', '0.9.1'), ('humanfriendly', '10.0'), ('hydra-core', '1.2.0'), ('hyperopt', '0.2.7'), ('idna', '3.4'), ('importlib-metadata', '3.10.1'), ('importlib-resources', '5.9.0'), ('infle ...
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Input In [8], in <cell line: 3>()
#       1 from tango import Workspace
#       2 workspace = Workspace.from_url("local:///root/workspace/read/temp/training")
# ----> 3 result = workspace.step_result_for_run("tapas_infotab_pipeline", "evaluation")
#
# File /opt/conda/envs/read/lib/python3.8/site-packages/tango/workspace.py:243, in Workspace.step_result_for_run(self, run_name, step_name)
#     241     return self.step_cache[step_info]
#     242 except KeyError:
# --> 243     raise KeyError(f"Step result for '{step_name}' not found in workspace")
#
# KeyError: "Step result for 'evaluation' not found in workspace"

# %%
result["result"]
# Out:
# {'document_retrieval': {'accuracy': 0.8399999737739563,
#   'recall': 0.8399999737739563,
#   'precision': 0.3162941336631775,
#   'mrr': 0.6867662072181702},
#  'sentence_selection': {'accuracy': 0.8409090638160706,
#   'recall': 0.8409090638160706,
#   'precision': 0.6481921672821045,
#   'mrr': 0.7708333730697632},
#  'table_verification': {'accuracy': 0.5,
#   'f1': 0.568965494632721,
#   'precision': 0.4583333432674408,
#   'recall': 0.75}}

# %%
result["failed_cases"]["document_retrieval"][1]
# Out:
# {'table': [{'Date': 'May 1953',
#    'Format': '10" LP',
#    'Label': 'RCA Victor',
#    'Edition': 'RCA Victor Presents Eartha Kitt',
#    'United States of Region': '',
#    'United Kingdom of Canada of South Africa of United States of United Kingdom of United States of France of United States of Region': ''},
#   {'Date': '1954',
#    'Format': '10" LP',
#    'Label': 'RCA Victor',
#    'Edition': '',
#    'United States of Region': '',
#    'United Kingdom of Canada of South Africa of United States of United Kingdom of United States of France of United States of Region': ''},
#   {'Date': '1955',
#    'Format': '10" LP (UK version)',
#    'Label': "His Master's Voice",
#    'Edition': 'That Bad Eartha (LP)',
#    'United States of Region': '',
#    'United Kingdom of Canada of South Africa of United States of United Kingdom of United States of France of United States of Region': ''},
#   {'Date': '1956',
#    'Format': '12" LP (standard version)',
#    'Label': 'RCA Victor',
#    'Edition': '',
#    'United States of Region': '',
#    'United Kingdom of Canada of South Africa of United States of United Kingdom of United States of France of United States of Region': ''},
#   {'Date': 'Unknown',
#    'Format': '7" EP (Japanese version)',
#    'Label': 'Victor',
#    'Edition': 'That Bad Eartha',
#    'United States of Region': '',
#    'United Kingdom of Canada of South Africa of United States of United Kingdom of United States of France of United States of Region': ''},
#   {'Date': '1980',
#    'Format': '12" LP (re-issue)',
#    'Label': 'RCA Victor',
#    'Edition': '"The Originals" That Bad Eartha',
#    'United States of Region': '',
#    'United Kingdom of Canada of South Africa of United States of United Kingdom of United States of France of United States of Region': ''},
#   {'Date': '1984',
#    'Format': '12" LP (re-issue), cassette (standard version), CD (standard version) (re-issued 1988-1989, 1992-1993, 1998, 2003 all under the original catalog #ND-89439)',
#    'Label': 'RCA',
#    'Edition': 'That Bad Eartha (LP)',
#    'United States of Region': '',
#    'United Kingdom of Canada of South Africa of United States of United Kingdom of United States of France of United States of Region': ''},
#   {'Date': '2002',
#    'Format': 'CD (standard version)',
#    'Label': 'BMG Special Products',
#    'Edition': 'That Bad Eartha / Down to Eartha',
#    'United States of Region': '',
#    'United Kingdom of Canada of South Africa of United States of United Kingdom of United States of France of United States of Region': ''},
#   {'Date': 'Unknown',
#    'Format': 'CD (standard version)',
#    'Label': 'RCA Records',
#    'Edition': 'That Bad Eartha (LP)',
#    'United States of Region': '',
#    'United Kingdom of Canada of South Africa of United States of United Kingdom of United States of France of United States of Region': ''},
#   {'Date': 'January 30, 2006',
#    'Format': 'CD (bonus track version)',
#    'Label': 'Universe Italy',
#    'Edition': '',
#    'United States of Region': '',
#    'United Kingdom of Canada of South Africa of United States of United Kingdom of United States of France of United States of Region': ''},
#   {'Date': 'November 27, 2006 (ret) (imp) (imp) / December 4, 2006 (lis)',
#    'Format': 'CD (standard version) (reconstructed artwork)',
#    'Label': 'Rev-Ola',
#    'Edition': '',
#    'United States of Region': '',
#    'United Kingdom of Canada of South Africa of United States of United Kingdom of United States of France of United States of Region': ''},
#   {'Date': 'Jan 30, 2007',
#    'Format': 'CD (standard version) (reconstructed artwork)',
#    'Label': 'Rev-Ola, Bear Family (dist)',
#    'Edition': '',
#    'United States of Region': '',
#    'United Kingdom of Canada of South Africa of United States of United Kingdom of United States of France of United States of Region': ''},
#   {'Date': 'November 20, 2007 (lis) / December 3, 2007 (ret)',
#    'Format': 'CD (standard version) (reconstructed artwork) (UK re-issue / IE first distributed issue), digital download (standard edition) (reconstructed artwork)',
#    'Label': 'Rev-Ola, Cherry Red (dist)',
#    'Edition': '',
#    'United States of Region': '',
#    'United Kingdom of Canada of South Africa of United States of United Kingdom of United States of France of United States of Region': ''},
#   {'Date': 'December 3, 2007 (ret)',
#    'Format': 'Digital download (standard version) (reconstructed artwork)',
#    'Label': 'Rev-Ola',
#    'Edition': '',
#    'United States of Region': '',
#    'United Kingdom of Canada of South Africa of United States of United Kingdom of United States of France of United States of Region': ''},
#   {'Date': '2008',
#    'Format': 'CD (UK version)',
#    'Label': 'Vocalation',
#    'Edition': 'That Bad Eartha & Down to Eartha',
#    'United States of Region': '',
#    'United Kingdom of Canada of South Africa of United States of United Kingdom of United States of France of United States of Region': ''},
#   {'Date': 'February 16, 2009 (ret) / February 19, 2009 (lis)',
#    'Format': '2xCD (standard version), digital download (standard version)',
#    'Label': 'Avid Easy',
#    'Edition': "Four Classic Albums (That Bad Eartha / Down to Eartha / Thursday's Child / St. Louis Blues)",
#    'United States of Region': '',
#    'United Kingdom of Canada of South Africa of United States of United Kingdom of United States of France of United States of Region': ''},
#   {'Date': '2010',
#    'Format': 'digital download',
#    'Label': 'Smith & Co',
#    'Edition': 'RCA Victor Presents Eartha Kitt',
#    'United States of Region': '',
#    'United Kingdom of Canada of South Africa of United States of United Kingdom of United States of France of United States of Region': ''},
#   {'Date': 'July 9, 2013',
#    'Format': '4xCD Box Set (standard version) [remastered]',
#    'Label': 'Real Gone Jazz',
#    'Edition': "7 Classic Albums (That Bad Eartha / Down to Eartha / Thursday's Child / St. Louis Blues / The Fabulous Eartha / Bad But Beautiful / The Romantic Eartha)",
#    'United States of Region': '',
#    'United Kingdom of Canada of South Africa of United States of United Kingdom of United States of France of United States of Region': ''}],
#  'table_webpage_url': 'http://en.wikipedia.org/wiki/That_Bad_Eartha',
#  'table_page_title': 'That Bad Eartha',
#  'table_section_title': 'Release history',
#  'table_section_text': '',
#  'highlighted_cells': [[16, 0], [16, 1], [16, 2]],
#  'example_id': -6574972035980525525,
#  'overlap_subset': False,
#  'sentence_annotations': [{'original_sentence': 'In 2010 it was issued as a digital download in select European countries under public domain with alternate artwork by Smith & Co. 10" Long Play Track list and notes adapted from liner notes of original release.Track lengths adapted from digital release.',
#    'sentence_after_deletion': 'In 2010 it was issued as a digital download by Smith & Co..',
#    'sentence_after_ambiguity': 'In 2010, That Bad Eartha was issued as a digital download by Smith & Co..',
#    'final_sentence': 'In 2010, That Bad Eartha was issued as a digital download by Smith & Co..'},
#   {'original_sentence': 'In 2010 it was issued as a digital download in select European countries under public domain with alternate artwork by Smith & Co. 10" Long Play Track list and notes adapted from liner notes of original release.Track lengths adapted from digital release.',
#    'sentence_after_deletion': 'In 2010 it was issued as a digital download by Smith & Co.',
#    'sentence_after_ambiguity': 'In 2010, That Bad Eartha was issued as a digital download by Smith & Co.',
#    'final_sentence': 'In 2010, That Bad Eartha was issued as a digital download by Smith & Co.'},
#   {'original_sentence': 'In 2010 it was issued as a digital download in select European countries under public domain with alternate artwork by Smith & Co. 10" Long Play Track list and notes adapted from liner notes of original release.Track lengths adapted from digital release.',
#    'sentence_after_deletion': 'In 2010 it was issued as a digital download by Smith & Co.',
#    'sentence_after_ambiguity': 'In 2010 That Bad Eartha was issued as a digital download by Smith & Co.',
#    'final_sentence': 'In 2010, That Bad Eartha was issued as a digital download by Smith & Co.'}],
#  'full_table_str': '<table> <row> <cell> Region </cell> <cell> Date <row_header> Region </row_header> </cell> <cell> Format <row_header> Region </row_header> <row_header> Date </row_header> </cell> <cell> Label <row_header> Region </row_header> <row_header> Date </row_header> <row_header> Format </row_header> </cell> <cell> Edition <row_header> Region </row_header> <row_header> Date </row_header> <row_header> Format </row_header> <row_header> Label </row_header> </cell> </row> <row> <cell> United States <col_header> Region </col_header> </cell> <cell> May 1953 <col_header> Date </col_header> <row_header> United States </row_header> </cell> <cell> 10" LP <col_header> Format </col_header> <row_header> United States </row_header> </cell> <cell> RCA Victor <col_header> Label </col_header> <row_header> United States </row_header> </cell> <cell> RCA Victor Presents Eartha Kitt <col_header> Edition </col_header> <row_header> United States </row_header> </cell> </row> <row> <cell> 1954 <col_header> Region </col_header> <col_header> United States </col_header> </cell> <cell> 2x7" Double EP <col_header> Date </col_header> </cell> </row> <row> <cell> 195? <col_header> Region </col_header> <col_header> United States </col_header> </cell> <cell> RCA <col_header> Date </col_header> </cell> </row> <row> <cell> France <col_header> Region </col_header> <col_header> United States </col_header> </cell> <cell> 1954 <col_header> Date </col_header> <row_header> France </row_header> </cell> <cell> 10" LP <col_header> Format </col_header> <row_header> France </row_header> </cell> <cell> RCA Victor <col_header> Label </col_header> <row_header> France </row_header> </cell> </row> <row> <cell> United States <col_header> Region </col_header> <col_header> United States </col_header> <col_header> France </col_header> </cell> <cell> 10" EP, 2x7" Double EP <col_header> Date </col_header> <row_header> United States </row_header> </cell> <cell> That Bad Eartha (EP) <col_header> Format </col_header> <row_header> United States </row_header> </cell> </row> <row> <cell> United Kingdom <col_header> Region </col_header> <col_header> United States </col_header> <col_header> France </col_header> <col_header> United States </col_header> </cell> <cell> 1955 <col_header> Date </col_header> <row_header> United Kingdom </row_header> </cell> <cell> 10" LP (UK version) <col_header> Format </col_header> <row_header> United Kingdom </row_header> </cell> <cell> His Master\'s Voice <col_header> Label </col_header> <row_header> United Kingdom </row_header> </cell> <cell> That Bad Eartha (LP) <col_header> Edition </col_header> <row_header> United Kingdom </row_header> </cell> </row> <row> <cell> United States <col_header> Region </col_header> <col_header> United States </col_header> <col_header> France </col_header> <col_header> United States </col_header> <col_header> United Kingdom </col_header> </cell> <cell> 1956 <col_header> Date </col_header> <row_header> United States </row_header> </cell> <cell> 12" LP (standard version) <col_header> Format </col_header> <row_header> United States </row_header> </cell> <cell> RCA Victor <col_header> Label </col_header> <row_header> United States </row_header> </cell> </row> <row> <cell> South Africa <col_header> Region </col_header> <col_header> United States </col_header> <col_header> France </col_header> <col_header> United States </col_header> <col_header> United Kingdom </col_header> <col_header> United States </col_header> </cell> <cell> RCA, Teal Records <col_header> Date </col_header> <row_header> South Africa </row_header> </cell> </row> <row> <cell> Canada <col_header> Region </col_header> <col_header> United States </col_header> <col_header> France </col_header> <col_header> United States </col_header> <col_header> United Kingdom </col_header> <col_header> United States </col_header> <col_header> South Africa </col_header> </cell> <cell> Unknown <col_header> Date </col_header> <row_header> Canada </row_header> </cell> <cell> RCA  ...
#  'subtable_str': '<table> <cell> 2010 <col_header> Date </col_header> <row_header> Ireland </row_header> </cell> <cell> digital download <col_header> Format </col_header> <row_header> Ireland </row_header> </cell> <cell> Smith & Co <col_header> Label </col_header> <row_header> Ireland </row_header> </cell> </table>',
#  'full_table_metadata_str': '<page_title> That Bad Eartha </page_title> <section_title> Release history </section_title> <table> <row> <cell> Region </cell> <cell> Date <row_header> Region </row_header> </cell> <cell> Format <row_header> Region </row_header> <row_header> Date </row_header> </cell> <cell> Label <row_header> Region </row_header> <row_header> Date </row_header> <row_header> Format </row_header> </cell> <cell> Edition <row_header> Region </row_header> <row_header> Date </row_header> <row_header> Format </row_header> <row_header> Label </row_header> </cell> </row> <row> <cell> United States <col_header> Region </col_header> </cell> <cell> May 1953 <col_header> Date </col_header> <row_header> United States </row_header> </cell> <cell> 10" LP <col_header> Format </col_header> <row_header> United States </row_header> </cell> <cell> RCA Victor <col_header> Label </col_header> <row_header> United States </row_header> </cell> <cell> RCA Victor Presents Eartha Kitt <col_header> Edition </col_header> <row_header> United States </row_header> </cell> </row> <row> <cell> 1954 <col_header> Region </col_header> <col_header> United States </col_header> </cell> <cell> 2x7" Double EP <col_header> Date </col_header> </cell> </row> <row> <cell> 195? <col_header> Region </col_header> <col_header> United States </col_header> </cell> <cell> RCA <col_header> Date </col_header> </cell> </row> <row> <cell> France <col_header> Region </col_header> <col_header> United States </col_header> </cell> <cell> 1954 <col_header> Date </col_header> <row_header> France </row_header> </cell> <cell> 10" LP <col_header> Format </col_header> <row_header> France </row_header> </cell> <cell> RCA Victor <col_header> Label </col_header> <row_header> France </row_header> </cell> </row> <row> <cell> United States <col_header> Region </col_header> <col_header> United States </col_header> <col_header> France </col_header> </cell> <cell> 10" EP, 2x7" Double EP <col_header> Date </col_header> <row_header> United States </row_header> </cell> <cell> That Bad Eartha (EP) <col_header> Format </col_header> <row_header> United States </row_header> </cell> </row> <row> <cell> United Kingdom <col_header> Region </col_header> <col_header> United States </col_header> <col_header> France </col_header> <col_header> United States </col_header> </cell> <cell> 1955 <col_header> Date </col_header> <row_header> United Kingdom </row_header> </cell> <cell> 10" LP (UK version) <col_header> Format </col_header> <row_header> United Kingdom </row_header> </cell> <cell> His Master\'s Voice <col_header> Label </col_header> <row_header> United Kingdom </row_header> </cell> <cell> That Bad Eartha (LP) <col_header> Edition </col_header> <row_header> United Kingdom </row_header> </cell> </row> <row> <cell> United States <col_header> Region </col_header> <col_header> United States </col_header> <col_header> France </col_header> <col_header> United States </col_header> <col_header> United Kingdom </col_header> </cell> <cell> 1956 <col_header> Date </col_header> <row_header> United States </row_header> </cell> <cell> 12" LP (standard version) <col_header> Format </col_header> <row_header> United States </row_header> </cell> <cell> RCA Victor <col_header> Label </col_header> <row_header> United States </row_header> </cell> </row> <row> <cell> South Africa <col_header> Region </col_header> <col_header> United States </col_header> <col_header> France </col_header> <col_header> United States </col_header> <col_header> United Kingdom </col_header> <col_header> United States </col_header> </cell> <cell> RCA, Teal Records <col_header> Date </col_header> <row_header> South Africa </row_header> </cell> </row> <row> <cell> Canada <col_header> Region </col_header> <col_header> United States </col_header> <col_header> France </col_header> <col_header> United States </col_header> <col_header> United Kingdom </col_header> <col_header> United States </col_header> <col_header> South Africa </col_header> </cell> ...
#  'subtable_metadata_str': '<page_title> That Bad Eartha </page_title> <section_title> Release history </section_title> <table> <cell> 2010 <col_header> Date </col_header> <row_header> Ireland </row_header> </cell> <cell> digital download <col_header> Format </col_header> <row_header> Ireland </row_header> </cell> <cell> Smith & Co <col_header> Label </col_header> <row_header> Ireland </row_header> </cell> </table>',
#  'num_numeric_headers': 0,
#  'sentence': 'In 2010 it was issued as a digital download in select European countries under public domain with alternate artwork by Smith & Co. 10" Long Play Track list and notes adapted from liner notes of original release.Track lengths adapted from digital release.',
#  'has_verb': True,
#  'valid_columns': [0, 1, 2],
#  'num_rows': 18,
#  'negatives': '',
#  'label': 1,
#  'linearized_table': '<page_title> That Bad Eartha </page_title> <section_title> Release history </section_title> <table> <cell> 2010 <col_header> Date </col_header> <row_header> Ireland </row_header> </cell> <cell> digital download <col_header> Format </col_header> <row_header> Ireland </row_header> </cell> <cell> Smith & Co <col_header> Label </col_header> <row_header> Ireland </row_header> </cell> </table>',
#  'title': 'That Bad Eartha'}

# %%
import torch
import json
from tango import Step
from tango.common.dataset_dict import DatasetDict
import pandas as pd
from transformers import TapasTokenizer

class TableDataset(torch.utils.data.Dataset):
    def __init__(self, df, tokenizer):
        self.df = df
        self.tokenizer = tokenizer

    def __getitem__(self, idx):
        ex_id = idx % 2
        idx = idx // 2
        item = self.df.iloc[idx]
        table = pd.DataFrame(json.loads(item["table"]))
        cells = zip(*item["highlighted_cells"])
        cells = [list(x) for x in cells]
        sub_table = table.iloc[cells[0], cells[1]].reset_index().astype(str)

        if ex_id == 0:
            encoding = self.tokenizer(
                table=sub_table,
                queries=item["positive"],
                padding="max_length",
                truncation=True,
                max_length=512,
                return_tensors="pt",
            )
            encoding["labels"] = torch.tensor([1])
        else:
            encoding = self.tokenizer(
                table=sub_table,
                queries=item["negative"],
                padding="max_length",
                truncation=True,
                max_length=512,
                return_tensors="pt",
            )
            encoding["labels"] = torch.tensor([0])

        encoding = {key: val[-1] for key, val in encoding.items()}
        return encoding

    def __len__(self):
        return len(self.df)

# %%
tokenizer = TapasTokenizer.from_pretrained("google/tapas-base", max_question_length=256)
torch.manual_seed(1)
dev_df = pd.read_json("../temp/seed/sent_selection/data/dev.jsonl", lines=True)

dev_dataset = TableDataset(dev_df, tokenizer)

# %%
from torch.utils.data import DataLoader
import accelerate

import evaluate
name2metrics = {
    "accuracy": evaluate.load("accuracy"),
    "precision": evaluate.load("precision"),
    "recall": evaluate.load("recall"),
    "f1": evaluate.load("f1"),
}

dataloader = DataLoader(dev_dataset, batch_size=8, shuffle=False)
accelerator = accelerate.Accelerator()

print(type(model))

model, dataloader = accelerator.prepare(model, dataloader)

for batch in dataloader:
    y_hat = model(**batch)
    preds = y_hat.logits.argmax(dim=1)
    for metric in name2metrics.values():
        metric.add_batch(predictions=preds, references=batch["labels"])
# Out:
# <class 'transformers.models.tapas.modeling_tapas.TapasForSequenceClassification'>

# %%
for name, metric in name2metrics.items():
    print(name, metric.compute())
# Out:
# accuracy {'accuracy': 0.9653325817361894}
# precision {'precision': 0.97524467472654}
# recall {'recall': 0.9549041713641488}
# f1 {'f1': 0.9649672457989177}
