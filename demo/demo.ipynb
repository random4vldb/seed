# %%
from huggingface_hub import snapshot_download

# %%
snapshot_download("clapika2010/dpr_finetuned_totto")
# Out:
# Downloading: 100%|██████████| 1.41k/1.41k [00:00<00:00, 1.19MB/s]
# Downloading: 100%|██████████| 4.89G/4.89G [02:17<00:00, 35.6MB/s]
# '/root/.cache/huggingface/hub/models--clapika2010--dpr_finetuned_totto/snapshots/79ceea8aab892ac1f46f6fcc3042260cbca2eea0'

# %%
import sys

sys.path.append("/root/workspace/read/")

# %%
from read.dpr.module import DPRModule

# %%
# Out:
# Some weights of the model checkpoint at facebook/dpr-question_encoder-multiset-base were not used when initializing DPRQuestionEncoder: ['question_encoder.bert_model.pooler.dense.weight', 'question_encoder.bert_model.pooler.dense.bias']
# - This IS expected if you are initializing DPRQuestionEncoder from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DPRQuestionEncoder from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of the model checkpoint at facebook/dpr-ctx_encoder-multiset-base were not used when initializing DPRContextEncoder: ['ctx_encoder.bert_model.pooler.dense.weight', 'ctx_encoder.bert_model.pooler.dense.bias']
# - This IS expected if you are initializing DPRContextEncoder from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DPRContextEncoder from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /root/workspace/read/demo/demo.ipynb Cell 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2B67.160.148.47/root/workspace/read/demo/demo.ipynb#X26sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> module = DPRModule.load_from_checkpoint("/root/.cache/huggingface/hub/models--clapika2010--dpr_finetuned_totto/snapshots/79ceea8aab892ac1f46f6fcc3042260cbca2eea0/temp/huggingface-hub/model.ckpt", num_labels=2, qry_encoder_name_or_path="facebook/dpr-question_encoder-multiset-base", ctx_encoder_name_or_path="facebook/dpr-ctx_encoder-multiset-base")
#
# File /opt/conda/envs/read/lib/python3.8/site-packages/pytorch_lightning/core/saving.py:137, in ModelIO.load_from_checkpoint(cls, checkpoint_path, map_location, hparams_file, strict, **kwargs)
#      57 @classmethod
#      58 def load_from_checkpoint(
#      59     cls,
#    (...)
#      64     **kwargs,
#      65 ):
#      66     r"""
#      67     Primary way of loading a model from a checkpoint. When Lightning saves a checkpoint
#      68     it stores the arguments passed to ``__init__``  in the checkpoint under ``"hyper_parameters"``.
#    (...)
#     135         y_hat = pretrained_model(x)
#     136     """
# --> 137     return _load_from_checkpoint(
#     138         cls,
#     139         checkpoint_path,
#     140         map_location,
#     141         hparams_file,
#     142         strict,
#     143         **kwargs,
#     144     )
#
# File /opt/conda/envs/read/lib/python3.8/site-packages/pytorch_lightning/core/saving.py:205, in _load_from_checkpoint(cls, checkpoint_path, map_location, hparams_file, strict, **kwargs)
#     203 if issubclass(cls, pl.LightningDataModule):
#     204     return _load_state(cls, checkpoint, **kwargs)
# --> 205 return _load_state(cls, checkpoint, strict=strict, **kwargs)
#
# File /opt/conda/envs/read/lib/python3.8/site-packages/pytorch_lightning/core/saving.py:259, in _load_state(cls, checkpoint, strict, **cls_kwargs_new)
#     256     return obj
#     258 # load the state_dict on the model automatically
# --> 259 keys = obj.load_state_dict(checkpoint["state_dict"], strict=strict)
#     261 if not strict:
#     262     if keys.missing_keys:
#
# File /opt/conda/envs/read/lib/python3.8/site-packages/torch/nn/modules/module.py:1604, in Module.load_state_dict(self, state_dict, strict)
#    1599         error_msgs.insert(
#    1600             0, 'Missing key(s) in state_dict: {}. '.format(
#    1601                 ', '.join('"{}"'.format(k) for k in missing_keys)))
#    1603 if len(error_msgs) > 0:
# -> 1604     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    1605                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    1606 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for DPRModule:
# 	Missing key(s) in state_dict: "model.qry_model.encoder.question_encoder.bert_model.embeddings.position_ids", "model.qry_model.encoder.question_encoder.bert_model.embeddings.word_embeddings.weight", "model.qry_model.encoder.question_encoder.bert_model.embeddings.position_embeddings.weight", "model.qry_model.encoder.question_encoder.bert_model.embeddings.token_type_embeddings.weight", "model.qry_model.encoder.question_encoder.bert_model.embeddings.LayerNorm.weight", "model.qry_model.encoder.question_encoder.bert_model.embeddings.LayerNorm.bias", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.0.attention.self.query.weight", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.0.attention.self.query.bias", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.0.attention.self.key.weight", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.0.attention.self.key.bias", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.0.attention.self.value.weight", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.0.attention.self.value.bias", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.0.attention.output.dense.weight", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.0.attention.output.dense.bias", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.0.attention.output.LayerNorm.weight", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.0.attention.output.LayerNorm.bias", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.0.intermediate.dense.weight", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.0.intermediate.dense.bias", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.0.output.dense.weight", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.0.output.dense.bias", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.0.output.LayerNorm.weight", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.0.output.LayerNorm.bias", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.1.attention.self.query.weight", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.1.attention.self.query.bias", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.1.attention.self.key.weight", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.1.attention.self.key.bias", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.1.attention.self.value.weight", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.1.attention.self.value.bias", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.1.attention.output.dense.weight", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.1.attention.output.dense.bias", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.1.attention.output.LayerNorm.weight", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.1.attention.output.LayerNorm.bias", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.1.intermediate.dense.weight", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.1.intermediate.dense.bias", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.1.output.dense.weight", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.1.output.dense.bias", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.1.output.LayerNorm.weight", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.1.output.LayerNorm.bias", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.2.attention.self.query.weight", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.2.attention.self.query.bias", "model.qry_model.encoder.question_encoder.bert_model.encoder.layer.2.attention.self.key.weight", "model.qry_model.encoder.question_encoder.bert_model ...
# 	Unexpected key(s) in state_dict: "model.model.shared.weight", "model.model.encoder.embed_tokens.weight", "model.model.encoder.embed_positions.weight", "model.model.encoder.layers.0.self_attn.k_proj.weight", "model.model.encoder.layers.0.self_attn.k_proj.bias", "model.model.encoder.layers.0.self_attn.v_proj.weight", "model.model.encoder.layers.0.self_attn.v_proj.bias", "model.model.encoder.layers.0.self_attn.q_proj.weight", "model.model.encoder.layers.0.self_attn.q_proj.bias", "model.model.encoder.layers.0.self_attn.out_proj.weight", "model.model.encoder.layers.0.self_attn.out_proj.bias", "model.model.encoder.layers.0.self_attn_layer_norm.weight", "model.model.encoder.layers.0.self_attn_layer_norm.bias", "model.model.encoder.layers.0.fc1.weight", "model.model.encoder.layers.0.fc1.bias", "model.model.encoder.layers.0.fc2.weight", "model.model.encoder.layers.0.fc2.bias", "model.model.encoder.layers.0.final_layer_norm.weight", "model.model.encoder.layers.0.final_layer_norm.bias", "model.model.encoder.layers.1.self_attn.k_proj.weight", "model.model.encoder.layers.1.self_attn.k_proj.bias", "model.model.encoder.layers.1.self_attn.v_proj.weight", "model.model.encoder.layers.1.self_attn.v_proj.bias", "model.model.encoder.layers.1.self_attn.q_proj.weight", "model.model.encoder.layers.1.self_attn.q_proj.bias", "model.model.encoder.layers.1.self_attn.out_proj.weight", "model.model.encoder.layers.1.self_attn.out_proj.bias", "model.model.encoder.layers.1.self_attn_layer_norm.weight", "model.model.encoder.layers.1.self_attn_layer_norm.bias", "model.model.encoder.layers.1.fc1.weight", "model.model.encoder.layers.1.fc1.bias", "model.model.encoder.layers.1.fc2.weight", "model.model.encoder.layers.1.fc2.bias", "model.model.encoder.layers.1.final_layer_norm.weight", "model.model.encoder.layers.1.final_layer_norm.bias", "model.model.encoder.layers.2.self_attn.k_proj.weight", "model.model.encoder.layers.2.self_attn.k_proj.bias", "model.model.encoder.layers.2.self_attn.v_proj.weight", "model.model.encoder.layers.2.self_attn.v_proj.bias", "model.model.encoder.layers.2.self_attn.q_proj.weight", "model.model.encoder.layers.2.self_attn.q_proj.bias", "model.model.encoder.layers.2.self_attn.out_proj.weight", "model.model.encoder.layers.2.self_attn.out_proj.bias", "model.model.encoder.layers.2.self_attn_layer_norm.weight", "model.model.encoder.layers.2.self_attn_layer_norm.bias", "model.model.encoder.layers.2.fc1.weight", "model.model.encoder.layers.2.fc1.bias", "model.model.encoder.layers.2.fc2.weight", "model.model.encoder.layers.2.fc2.bias", "model.model.encoder.layers.2.final_layer_norm.weight", "model.model.encoder.layers.2.final_layer_norm.bias", "model.model.encoder.layers.3.self_attn.k_proj.weight", "model.model.encoder.layers.3.self_attn.k_proj.bias", "model.model.encoder.layers.3.self_attn.v_proj.weight", "model.model.encoder.layers.3.self_attn.v_proj.bias", "model.model.encoder.layers.3.self_attn.q_proj.weight", "model.model.encoder.layers.3.self_attn.q_proj.bias", "model.model.encoder.layers.3.self_attn.out_proj.weight", "model.model.encoder.layers.3.self_attn.out_proj.bias", "model.model.encoder.layers.3.self_attn_layer_norm.weight", "model.model.encoder.layers.3.self_attn_layer_norm.bias", "model.model.encoder.layers.3.fc1.weight", "model.model.encoder.layers.3.fc1.bias", "model.model.encoder.layers.3.fc2.weight", "model.model.encoder.layers.3.fc2.bias", "model.model.encoder.layers.3.final_layer_norm.weight", "model.model.encoder.layers.3.final_layer_norm.bias", "model.model.encoder.layers.4.self_attn.k_proj.weight", "model.model.encoder.layers.4.self_attn.k_proj.bias", "model.model.encoder.layers.4.self_attn.v_proj.weight", "model.model.encoder.layers.4.self_attn.v_proj.bias", "model.model.encoder.layers.4.self_attn.q_proj.weight", "model.model.encoder.layers.4.self_attn.q_proj.bias", "model.model.encoder.layers.4.self_attn.out_proj.weight", "model.model.encoder.layers.4.self_attn.out_proj.bias", "model.model.encoder.layers.4.self_attn_laye ...
